# %% [markdown]
# # 一、 数据获取余票数据

# %% [markdown]
# # 1.几行简单代码获取某区间某日所有余票数据

# %% [markdown]
# ## 1.1读取SHANGHAI-SUZHOU单个页面数据

# %% [markdown]
# 首先要分析网站，怎么样才能获取数据

# %%
import requests
import json

# %%
url = 'https://kyfw.12306.cn/otn/lcxxcx/query?purpose_codes=ADULT&queryDate=2016-12-29&from_station=SHH&to_station=NJH'

# %%
js = requests.get(url).text
# Out:
# /Library/Python/2.7/site-packages/requests/packages/urllib3/util/ssl_.py:315: SNIMissingWarning: An HTTPS request has been made, but the SNI (Subject Name Indication) extension to TLS is not available on this platform. This may cause the server to present an incorrect TLS certificate, which can cause validation failures. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#snimissingwarning.
#   SNIMissingWarning
# /Library/Python/2.7/site-packages/requests/packages/urllib3/util/ssl_.py:120: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# <ipython-input-3-4e3c2395b470> in <module>()
# ----> 1 js = requests.get(url).text
#
# /Library/Python/2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      65
#      66     kwargs.setdefault('allow_redirects', True)
# ---> 67     return request('get', url, params=params, **kwargs)
#      68
#      69
#
# /Library/Python/2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      51     # cases, and look like a memory leak in others.
#      52     with sessions.Session() as session:
# ---> 53         return session.request(method=method, url=url, **kwargs)
#      54
#      55
#
# /Library/Python/2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# /Library/Python/2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# /Library/Python/2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     445         except (_SSLError, _HTTPError) as e:
#     446             if isinstance(e, _SSLError):
# --> 447                 raise SSLError(e, request=request)
#     448             elif isinstance(e, ReadTimeoutError):
#     449                 raise ReadTimeout(e, request=request)
#
# SSLError: [Errno 1] _ssl.c:507: error:14090086:SSL routines:SSL3_GET_SERVER_CERTIFICATE:certificate verify failed

# %% [markdown]
# https://promotion.aliyun.com/ntms/act/globalhttps.html?spm=5176.8142029.418686.5.yBwhSy<br>
# HTTPS在HTTP的基础上加入了SSL/TLS协议，依靠SSL证书来验证服务器的身份，并为客户端和服务器端之间建立“SSL加密通道”，确保用户数据在传输过程中处于加密状态，同时防止服务器被钓鱼网站假冒。

# %%
js = requests.get(url,verify=False).text

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
js = requests.get(url,verify=False).text

# %%
js2 = json.loads(js)

# %%
data = js2['data']['datas']

# %%
data
# Out:
# [{u'arrive_time': u'05:31',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0705',
#   u'end_province_code': u'07',
#   u'end_station_name': u'\u5357\u4eac',
#   u'end_station_telecode': u'NJH',
#   u'from_station_name': u'\u4e0a\u6d77\u5357',
#   u'from_station_no': u'14',
#   u'from_station_telecode': u'SNH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'0',
#   u'lishi': u'01:17',
#   u'lishiValue': u'77',
#   u'location_code': u'G1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'11',
#   u'rz_num': u'--',
#   u'sale_time': u'1530',
#   u'seat_feature': u'W3431333',
#   u'seat_types': u'1413',
#   u'start_city_code': u'1004',
#   u'start_province_code': u'10',
#   u'start_station_name': u'\u798f\u5dde',
#   u'start_station_telecode': u'FZS',
#   u'start_time': u'04:14',
#   u'start_train_date': u'20161228',
#   u'station_train_code': u'K526',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'15',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'580000K52606',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'322',
#   u'yb_num': u'--',
#   u'yp_ex': u'10401030',
#   u'yp_info': u'2qI5iP6NO089WO62KUeJ%2BOiyKm6%2BaZ0u1opzaz%2B%2FD2X6GOqUeagEnEnyb7c%3D',
#   u'yw_num': u'91',
#   u'yz_num': u'528',
#   u'ze_num': u'--',
#   u'zy_num': u'--'},
#  {u'arrive_time': u'05:38',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0705',
#   u'end_province_code': u'07',
#   u'end_station_name': u'\u5357\u4eac',
#   u'end_station_telecode': u'NJH',
#   u'from_station_name': u'\u4e0a\u6d77\u5357',
#   u'from_station_no': u'20',
#   u'from_station_telecode': u'SNH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'0',
#   u'lishi': u'01:09',
#   u'lishiValue': u'69',
#   u'location_code': u'Q7',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'\u65e0',
#   u'rz_num': u'--',
#   u'sale_time': u'1530',
#   u'seat_feature': u'W3431333',
#   u'seat_types': u'1413',
#   u'start_city_code': u'1502',
#   u'start_province_code': u'16',
#   u'start_station_name': u'\u5e7f\u5dde',
#   u'start_station_telecode': u'GZQ',
#   u'start_time': u'04:29',
#   u'start_train_date': u'20161228',
#   u'station_train_code': u'K528',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'21',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'630000K5280K',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'10401030',
#   u'yp_info': u'EI4Ip%2B1i80plUz4ndoOA1KLaJd3y%2BvZHhyCGR%2FkBfXe3NDhA4Ylyh%2FsT2Ek%3D',
#   u'yw_num': u'16',
#   u'yz_num': u'295',
#   u'ze_num': u'--',
#   u'zy_num': u'--'},
#  {u'arrive_time': u'06:41',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'1707',
#   u'end_province_code': u'19',
#   u'end_station_name': u'\u6210\u90fd\u4e1c',
#   u'end_station_telecode': u'ICW',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:32',
#   u'lishiValue': u'32',
#   u'location_code': u'H2',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M3W3',
#   u'seat_types': u'OMO',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'06:09',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'D636',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'\u52a8\u8f66',
#   u'train_no': u'5l0000D63630',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M0O0',
#   u'yp_info': u'oJdpd6vDwCn5U6wHPQSaWRtfF89ZPh1AYOxmtZnoo23V75HW',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'75',
#   u'zy_num': u'11'},
#  {u'arrive_time': u'06:40',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'2003',
#   u'end_province_code': u'23',
#   u'end_station_name': u'\u897f\u5b89\u5317',
#   u'end_station_telecode': u'EAY',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:23',
#   u'lishiValue': u'23',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'OM9',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'06:17',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G1912',
#   u'swz_num': u'23',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l000G191200',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M090',
#   u'yp_info': u'MLRRkOrwXno5PHoT6uzVH%2FnR6nvkqEHpEyYDtkLGTpMQBQ0y',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'707',
#   u'zy_num': u'160'},
#  {u'arrive_time': u'06:50',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0705',
#   u'end_province_code': u'07',
#   u'end_station_name': u'\u5357\u4eac',
#   u'end_station_telecode': u'NJH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:32',
#   u'lishiValue': u'32',
#   u'location_code': u'H3',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O3W3M3',
#   u'seat_types': u'OOM',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'06:18',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7032',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G703240',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0O0M0',
#   u'yp_info': u'8Dc3rX%2BHIH2mumyslPLhh4jVHmGEwWxtNdCJExXMmZa3O4Nw',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'522',
#   u'zy_num': u'50'},
#  {u'arrive_time': u'06:45',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'1222',
#   u'end_province_code': u'13',
#   u'end_station_name': u'\u90d1\u5dde\u4e1c',
#   u'end_station_telecode': u'ZAF',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:23',
#   u'lishiValue': u'23',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'OM9',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'06:22',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G1802',
#   u'swz_num': u'\u65e0',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l000G180200',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M090',
#   u'yp_info': u'b088%2Fwy0E6WoKauTDpKCY3pmBN3OzlnC%2FZOPFUf0DjnuIKC6',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'448',
#   u'zy_num': u'17'},
#  {u'arrive_time': u'06:55',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0816',
#   u'end_province_code': u'09',
#   u'end_station_name': u'\u5b89\u5e86',
#   u'end_station_telecode': u'AQH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:32',
#   u'lishiValue': u'32',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O3M3W3',
#   u'seat_types': u'OMO',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'06:23',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7076',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G7076A0',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M0O0',
#   u'yp_info': u'717aS1oRRTCmdbtvn0jDhTkim2c%2FJZdz4cUVxPLL74H3lUqo',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'63',
#   u'zy_num': u'3'},
#  {u'arrive_time': u'07:16',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'1707',
#   u'end_province_code': u'19',
#   u'end_station_name': u'\u6210\u90fd\u4e1c',
#   u'end_station_telecode': u'ICW',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:38',
#   u'lishiValue': u'38',
#   u'location_code': u'H2',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M3W3',
#   u'seat_types': u'OMO',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'06:38',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'D2206',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'\u52a8\u8f66',
#   u'train_no': u'5l000D220651',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M0O0',
#   u'yp_info': u'pmJE8Z8d8aal62Z1in4SQEDdm36YrQLBn5uFYGDP%2FntcldB0',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'366',
#   u'zy_num': u'35'},
#  {u'arrive_time': u'07:02',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0357',
#   u'end_province_code': u'31',
#   u'end_station_name': u'\u5317\u4eac\u5357',
#   u'end_station_telecode': u'VNP',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:23',
#   u'lishiValue': u'23',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'OM9',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'06:39',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G102',
#   u'swz_num': u'\u65e0',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l0000G10261',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M090',
#   u'yp_info': u'AlGcXWgyP9R%2BiPoA7CNfY3PDkARve2AQopk71dCn9uYkNefx',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'143',
#   u'zy_num': u'49'},
#  {u'arrive_time': u'07:34',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'1307',
#   u'end_province_code': u'14',
#   u'end_station_name': u'\u5b9c\u660c\u4e1c',
#   u'end_station_telecode': u'HAN',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:44',
#   u'lishiValue': u'44',
#   u'location_code': u'H3',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M3W3',
#   u'seat_types': u'OMO',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'06:50',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'D3072',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'\u52a8\u8f66',
#   u'train_no': u'5l000D307230',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M0O0',
#   u'yp_info': u'oE%2BckYoHdjN2XiafEA3szm6eSSieKbyc6GEOKbFeV5m%2BQbPs',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'254',
#   u'zy_num': u'67'},
#  {u'arrive_time': u'07:25',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0705',
#   u'end_province_code': u'07',
#   u'end_station_name': u'\u5357\u4eac',
#   u'end_station_telecode': u'NJH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:25',
#   u'lishiValue': u'25',
#   u'location_code': u'H3',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O3M3W3P3',
#   u'seat_types': u'OOMP',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'07:00',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7002',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G700261',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'24',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0O0M0P0',
#   u'yp_info': u'B%2BVqfqpgY3lkjh9bBDDHtEWP95B4M3scNPaLeKjha20tqLVbNS4%2FQ0ZFoTE%3D',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'988',
#   u'zy_num': u'64'},
#  {u'arrive_time': u'07:39',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0705',
#   u'end_province_code': u'07',
#   u'end_station_name': u'\u5357\u4eac',
#   u'end_station_telecode': u'NJH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:34',
#   u'lishiValue': u'34',
#   u'location_code': u'H3',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O3M3W3',
#   u'seat_types': u'OMO',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'07:05',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7034',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G703450',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M0O0',
#   u'yp_info': u'3pIdc6uxLTjssub3JfiZIMf5dNpR6yj0FyVpnmdWRbI0EwQs',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'530',
#   u'zy_num': u'50'},
#  {u'arrive_time': u'07:33',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0357',
#   u'end_province_code': u'31',
#   u'end_station_name': u'\u5317\u4eac\u5357',
#   u'end_station_telecode': u'VNP',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:23',
#   u'lishiValue': u'23',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'OM9',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'07:10',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G106',
#   u'swz_num': u'15',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l0000G10651',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M090',
#   u'yp_info': u'QiwhNjjDqqYytVDFTpzsd%2Bsx2A%2BWaclLdIofwNQenntZOKZc',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'345',
#   u'zy_num': u'28'},
#  {u'arrive_time': u'07:39',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'2003',
#   u'end_province_code': u'23',
#   u'end_station_name': u'\u897f\u5b89\u5317',
#   u'end_station_telecode': u'EAY',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:24',
#   u'lishiValue': u'24',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'O9M',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'07:15',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G1916',
#   u'swz_num': u'25',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l000G191600',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O090M0',
#   u'yp_info': u'oGJn4l71317BF63m1uUorOdXaUKulHbAlkvo%2BN2Quc4acJR4',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'667',
#   u'zy_num': u'167'},
#  {u'arrive_time': u'07:50',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'1314',
#   u'end_province_code': u'14',
#   u'end_station_name': u'\u6c49\u53e3',
#   u'end_station_telecode': u'HKN',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:35',
#   u'lishiValue': u'35',
#   u'location_code': u'H2',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M3W3',
#   u'seat_types': u'OMO',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'07:15',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'D3056',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'\u52a8\u8f66',
#   u'train_no': u'5l000D305630',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'84',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M0O0',
#   u'yp_info': u'gF8lgiCf1A%2BBawT59IOjglqQRFEpyDGveGe2D4TYIwHRNTzX',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'47',
#   u'zy_num': u'1'},
#  {u'arrive_time': u'08:00',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0705',
#   u'end_province_code': u'07',
#   u'end_station_name': u'\u5357\u4eac',
#   u'end_station_telecode': u'NJH',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:40',
#   u'lishiValue': u'40',
#   u'location_code': u'H3',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O393W3M3',
#   u'seat_types': u'O9MO',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'07:20',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7102',
#   u'swz_num': u'10',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'04',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'5l000G710240',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O090M0O0',
#   u'yp_info': u'8rDUVImzhzjzyfbAyW1gqZOsQSq874CLIDDzKJ2TRkcmyGcbkr%2FdTzJvxaM%3D',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'467',
#   u'zy_num': u'28'},
#  {u'arrive_time': u'07:53',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0357',
#   u'end_province_code': u'31',
#   u'end_station_name': u'\u5317\u4eac\u5357',
#   u'end_station_telecode': u'VNP',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:25',
#   u'lishiValue': u'25',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'OM9',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'07:28',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G110',
#   u'swz_num': u'12',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l0000G11091',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M090',
#   u'yp_info': u'RZk1MgBKhTws%2Fu7bLoGr3ialh2gEtAGel8OAsQ3bV%2F5FcRs2',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'279',
#   u'zy_num': u'45'},
#  {u'arrive_time': u'08:08',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'1717',
#   u'end_province_code': u'34',
#   u'end_station_name': u'\u91cd\u5e86\u5317',
#   u'end_station_telecode': u'CUW',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:38',
#   u'lishiValue': u'38',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M3W3',
#   u'seat_types': u'OMO',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'07:30',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'D2212',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'\u52a8\u8f66',
#   u'train_no': u'5l000D221221',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M0O0',
#   u'yp_info': u'wH2FfoSH0S3ngjmGPSICekXrsuD6kmksfFAPr6KWM69Fwjp1',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'100',
#   u'zy_num': u'17'},
#  {u'arrive_time': u'08:14',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0816',
#   u'end_province_code': u'09',
#   u'end_station_name': u'\u5b89\u5e86',
#   u'end_station_telecode': u'AQH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:31',
#   u'lishiValue': u'31',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O393W3M3',
#   u'seat_types': u'O9MO',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'07:43',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7080',
#   u'swz_num': u'12',
#   u'to_station_name': u'\u82cf\u5dde\u56ed\u533a',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'KAH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G708090',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O090M0O0',
#   u'yp_info': u'3vUHqbJWQNkp6V08YRNceWBVKvTt6lAfBfzB2ar783Hlg3B1NJeycCkdFt8%3D',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'19',
#   u'zy_num': u'28'},
#  {u'arrive_time': u'08:33',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0210',
#   u'end_province_code': u'04',
#   u'end_station_name': u'\u4e39\u4e1c',
#   u'end_station_telecode': u'DUT',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:44',
#   u'lishiValue': u'44',
#   u'location_code': u'H2',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'OM9',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'07:49',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G1232',
#   u'swz_num': u'1',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l000G123280',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M090',
#   u'yp_info': u'BPqWk0Sv%2F6vwDjNwqBhzMk%2BMc6ZUGQeE1a4RQS7T40Lo1a%2F%2F',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'18',
#   u'zy_num': u'2'},
#  {u'arrive_time': u'08:25',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0705',
#   u'end_province_code': u'07',
#   u'end_station_name': u'\u5357\u4eac',
#   u'end_station_telecode': u'NJH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:25',
#   u'lishiValue': u'25',
#   u'location_code': u'H3',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O3W3M3P3',
#   u'seat_types': u'OMOP',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'08:00',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7004',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G700482',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'15',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M0O0P0',
#   u'yp_info': u'nm%2FkslnhQnxSemYqlB8I3eDw9jbpd7gK5GN8PA9FkMG3X0neUJ%2FvmXP51bw%3D',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'951',
#   u'zy_num': u'32'},
#  {u'arrive_time': u'08:37',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0805',
#   u'end_province_code': u'09',
#   u'end_station_name': u'\u6dee\u5357\u4e1c',
#   u'end_station_telecode': u'HOH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:32',
#   u'lishiValue': u'32',
#   u'location_code': u'H2',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O3M3W3',
#   u'seat_types': u'OMO',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'08:05',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7268',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G726830',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M0O0',
#   u'yp_info': u'zDO8fwwzI7M5YEtxigCwelCkwuAJG2w0rewMIqTlH%2FfUJ%2F4t',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'317',
#   u'zy_num': u'95'},
#  {u'arrive_time': u'08:28',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0357',
#   u'end_province_code': u'31',
#   u'end_station_name': u'\u5317\u4eac\u5357',
#   u'end_station_telecode': u'VNP',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:23',
#   u'lishiValue': u'23',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'OM9',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'08:05',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G112',
#   u'swz_num': u'3',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l0000G11291',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M090',
#   u'yp_info': u'kZKDPOw8c4Qd%2BsuvknXMyUrpreffmZcG50nXi2WZmc4W8Ego',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'343',
#   u'zy_num': u'32'},
#  {u'arrive_time': u'08:42',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0705',
#   u'end_province_code': u'07',
#   u'end_station_name': u'\u5357\u4eac',
#   u'end_station_telecode': u'NJH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:32',
#   u'lishiValue': u'32',
#   u'location_code': u'H2',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O393M3W3',
#   u'seat_types': u'O9OM',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'08:10',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7036',
#   u'swz_num': u'10',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G703670',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O090O0M0',
#   u'yp_info': u'rzPkuSv3Ok8msgbal2kDLeFIgv5QOi5PqMyf556Tv6N%2BjMjDsvMWXR9Ntnk%3D',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'480',
#   u'zy_num': u'27'},
#  {u'arrive_time': u'08:43',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0357',
#   u'end_province_code': u'31',
#   u'end_station_name': u'\u5317\u4eac\u5357',
#   u'end_station_telecode': u'VNP',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:33',
#   u'lishiValue': u'33',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'OM9',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'08:10',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G114',
#   u'swz_num': u'2',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l0000G11441',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M090',
#   u'yp_info': u'BmXh2%2F8IZlF7Q52Hp13VO1hbQzOH%2FVT%2FrjQpDyR3JN%2F84LUw',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'177',
#   u'zy_num': u'2'},
#  {u'arrive_time': u'08:47',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0819',
#   u'end_province_code': u'09',
#   u'end_station_name': u'\u516d\u5b89',
#   u'end_station_telecode': u'UAH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:32',
#   u'lishiValue': u'32',
#   u'location_code': u'H2',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O393M3W3',
#   u'seat_types': u'O9OM',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'08:15',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7232',
#   u'swz_num': u'5',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G723280',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O090O0M0',
#   u'yp_info': u'XOTPYcnuhS0KJQ%2FuYHkDtl51lYh5CO%2FgSoGqv%2FwlCuiJOOwGc8J2KKWMs5k%3D',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'65',
#   u'zy_num': u'1'},
#  {u'arrive_time': u'08:39',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0405',
#   u'end_province_code': u'02',
#   u'end_station_name': u'\u592a\u539f\u5357',
#   u'end_station_telecode': u'TNV',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:23',
#   u'lishiValue': u'23',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'OM9',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'08:16',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G1952',
#   u'swz_num': u'1',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l000G195200',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M090',
#   u'yp_info': u'RPI8vpV6nXjKWMatIyrkpccg2y2IGl3iavhjdmQkxC4kLlMm',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'384',
#   u'zy_num': u'9'},
#  {u'arrive_time': u'08:54',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'1314',
#   u'end_province_code': u'14',
#   u'end_station_name': u'\u6c49\u53e3',
#   u'end_station_telecode': u'HKN',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:34',
#   u'lishiValue': u'34',
#   u'location_code': u'H3',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3W3M3',
#   u'seat_types': u'OOM',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'08:20',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'D3064',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'\u52a8\u8f66',
#   u'train_no': u'5l000D306430',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0O0M0',
#   u'yp_info': u'zqRH4xme1VV4UlRSJHDBOr4LotZ6YPfnF5dBV%2BbDsAAThvzi',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'47',
#   u'zy_num': u'16'},
#  {u'arrive_time': u'08:48',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'1407',
#   u'end_province_code': u'15',
#   u'end_station_name': u'\u957f\u6c99\u5357',
#   u'end_station_telecode': u'CWQ',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:23',
#   u'lishiValue': u'23',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'OM9',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'08:25',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G576',
#   u'swz_num': u'6',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l0000G57640',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M090',
#   u'yp_info': u'npkgW8a0xYIjOQbvGs0pQRnm52uaes59CcEyyml%2F7skj07kx',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'300',
#   u'zy_num': u'11'},
#  {u'arrive_time': u'09:07',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0710',
#   u'end_province_code': u'07',
#   u'end_station_name': u'\u82cf\u5dde',
#   u'end_station_telecode': u'SZH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:41',
#   u'lishiValue': u'41',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O3W3M3',
#   u'seat_types': u'OOM',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'08:26',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7206',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'04',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G720690',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0O0M0',
#   u'yp_info': u'8Dc3rX%2BHIH2mumyslPLhh4jVHmGEwWxtNdCJExXMmZa3O4Nw',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'522',
#   u'zy_num': u'50'},
#  {u'arrive_time': u'08:55',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'1314',
#   u'end_province_code': u'14',
#   u'end_station_name': u'\u6b66\u6c49',
#   u'end_station_telecode': u'WHN',
#   u'from_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'AOH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:23',
#   u'lishiValue': u'23',
#   u'location_code': u'H2',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1330',
#   u'seat_feature': u'O3M393',
#   u'seat_types': u'OM9',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77\u8679\u6865',
#   u'start_station_telecode': u'AOH',
#   u'start_time': u'08:32',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G676',
#   u'swz_num': u'\u65e0',
#   u'to_station_name': u'\u82cf\u5dde\u5317',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'OHH',
#   u'train_class_name': u'',
#   u'train_no': u'5l0000G67630',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0M090',
#   u'yp_info': u'cB2tywUod5IFhEFGgiw3n%2Fp3KJm2XErDZ1hnQqnG8j8rqi3T',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'43',
#   u'zy_num': u'4'},
#  {u'arrive_time': u'09:11',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0816',
#   u'end_province_code': u'09',
# ...
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'21:46',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'K8482',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000K8482D5',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'116',
#   u'yb_num': u'--',
#   u'yp_ex': u'10403010',
#   u'yp_info': u'YG0kyivwowa5dyNG4qAxKHfTtQ6pwVNh6ISyzAmtWqo0SE%2BW9WwPtfErK%2F8%3D',
#   u'yw_num': u'8',
#   u'yz_num': u'158',
#   u'ze_num': u'--',
#   u'zy_num': u'--'},
#  {u'arrive_time': u'22:47',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0710',
#   u'end_province_code': u'07',
#   u'end_station_name': u'\u82cf\u5dde',
#   u'end_station_telecode': u'SZH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:34',
#   u'lishiValue': u'34',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O3W3M3',
#   u'seat_types': u'OOM',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'22:13',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7210',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G7210E0',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O0O0M0',
#   u'yp_info': u'Dr486eBb%2B4O%2B6bGZX2CDq7ptakd2XAttUalHKIFsvY6nKPkr',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'533',
#   u'zy_num': u'50'},
#  {u'arrive_time': u'23:47',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0801',
#   u'end_province_code': u'09',
#   u'end_station_name': u'\u6dee\u5317',
#   u'end_station_telecode': u'HRH',
#   u'from_station_name': u'\u4e0a\u6d77\u5357',
#   u'from_station_no': u'10',
#   u'from_station_telecode': u'SNH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'0',
#   u'lishi': u'01:27',
#   u'lishiValue': u'87',
#   u'location_code': u'H2',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'14',
#   u'rz_num': u'--',
#   u'sale_time': u'1530',
#   u'seat_feature': u'W3431333',
#   u'seat_types': u'1413',
#   u'start_city_code': u'0917',
#   u'start_province_code': u'08',
#   u'start_station_name': u'\u6c5f\u5c71',
#   u'start_station_telecode': u'JUH',
#   u'start_time': u'22:20',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'K8372',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'12',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'56000K837273',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'178',
#   u'yb_num': u'--',
#   u'yp_ex': u'10401030',
#   u'yp_info': u'kMg21CtBACP2YzS36AbV0Z6jV1ax6BG4%2BSE5QFPGe3nohhOb7kg8f55tegY%3D',
#   u'yw_num': u'4',
#   u'yz_num': u'89',
#   u'ze_num': u'--',
#   u'zy_num': u'--'},
#  {u'arrive_time': u'23:10',
#   u'canWebBuy': u'Y',
#   u'control_day': 19,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'2003',
#   u'end_province_code': u'23',
#   u'end_station_name': u'\u897f\u5b89\u5317',
#   u'end_station_telecode': u'EAY',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'11',
#   u'is_support_card': u'1',
#   u'lishi': u'00:46',
#   u'lishiValue': u'46',
#   u'location_code': u'H2',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'10',
#   u'rz_num': u'--',
#   u'sale_time': u'0800',
#   u'seat_feature': u'O36343',
#   u'seat_types': u'6O4',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'22:24',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'D306',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'\u52a8\u8f66',
#   u'train_no': u'550000D30661',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'--',
#   u'yb_num': u'--',
#   u'yp_ex': u'60O040',
#   u'yp_info': u'Hqs7qCf2Fg%2BcdH%2F2k4hCLMVjvWch1wOpfPpGRAtw5RnqGARp',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'67',
#   u'zy_num': u'--'},
#  {u'arrive_time': u'00:06',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'1',
#   u'end_city_code': u'0602',
#   u'end_province_code': u'12',
#   u'end_station_name': u'\u6d4e\u5357',
#   u'end_station_telecode': u'JNK',
#   u'from_station_name': u'\u4e0a\u6d77\u5357',
#   u'from_station_no': u'08',
#   u'from_station_telecode': u'SNH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'0',
#   u'lishi': u'01:26',
#   u'lishiValue': u'86',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'9',
#   u'rz_num': u'--',
#   u'sale_time': u'1530',
#   u'seat_feature': u'W3431333',
#   u'seat_types': u'1413',
#   u'start_city_code': u'0910',
#   u'start_province_code': u'08',
#   u'start_station_name': u'\u5b81\u6ce2',
#   u'start_station_telecode': u'NGH',
#   u'start_time': u'22:40',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'T136',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'10',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'5e0000T13610',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'120',
#   u'yb_num': u'--',
#   u'yp_ex': u'10401030',
#   u'yp_info': u'BHe4nLi3OIOt4CU6kY%2FrICP2EOjCymvl8GpNtjZs%2Fm5qTNuLGFHZPhHRQCs%3D',
#   u'yw_num': u'24',
#   u'yz_num': u'183',
#   u'ze_num': u'--',
#   u'zy_num': u'--'},
#  {u'arrive_time': u'23:15',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'0',
#   u'end_city_code': u'0710',
#   u'end_province_code': u'07',
#   u'end_station_name': u'\u82cf\u5dde',
#   u'end_station_telecode': u'SZH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'1',
#   u'lishi': u'00:34',
#   u'lishiValue': u'34',
#   u'location_code': u'H3',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'O393W3M3',
#   u'seat_types': u'O9MO',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'22:41',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'G7212',
#   u'swz_num': u'10',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000G721230',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'O090M0O0',
#   u'yp_info': u'9Tft4g79owicIN1GUCfxbTdhDEvKtpu7BT7Gd%2BBDSuoZV1Q3jmX99A4QCfE%3D',
#   u'yw_num': u'--',
#   u'yz_num': u'--',
#   u'ze_num': u'477',
#   u'zy_num': u'28'},
#  {u'arrive_time': u'00:16',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'1',
#   u'end_city_code': u'0804',
#   u'end_province_code': u'09',
#   u'end_station_name': u'\u961c\u9633',
#   u'end_station_telecode': u'FYH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'0',
#   u'lishi': u'01:03',
#   u'lishiValue': u'63',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'2',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'W3431333',
#   u'seat_types': u'1413',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'23:13',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'K8386',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000K838610',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'10401030',
#   u'yp_info': u'sX0XY4eoTN1sECwi4KhiChNx3noOuc8JHf8i%2BlyzxQk0PlaNPndM2DBT%2BsU%3D',
#   u'yw_num': u'\u65e0',
#   u'yz_num': u'119',
#   u'ze_num': u'--',
#   u'zy_num': u'--'},
#  {u'arrive_time': u'00:22',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'1',
#   u'end_city_code': u'0801',
#   u'end_province_code': u'09',
#   u'end_station_name': u'\u6dee\u5317',
#   u'end_station_telecode': u'HRH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'0',
#   u'lishi': u'01:02',
#   u'lishiValue': u'62',
#   u'location_code': u'H2',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'1',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'W3431333',
#   u'seat_types': u'1413',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'23:20',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'K8432',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000K843264',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'426',
#   u'yb_num': u'--',
#   u'yp_ex': u'10401030',
#   u'yp_info': u'fHTewh1ku09J8SkltVCFAtFKb%2FFeT8qvp70t1oUApxG0skcqj61Et9IR%2BM8%3D',
#   u'yw_num': u'7',
#   u'yz_num': u'35',
#   u'ze_num': u'--',
#   u'zy_num': u'--'},
#  {u'arrive_time': u'00:36',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'1',
#   u'end_city_code': u'0804',
#   u'end_province_code': u'09',
#   u'end_station_name': u'\u961c\u9633',
#   u'end_station_telecode': u'FYH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'0',
#   u'lishi': u'01:01',
#   u'lishiValue': u'61',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'--',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'W31333',
#   u'seat_types': u'113',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'23:35',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'K8362',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'02',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000K8362D1',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'101030',
#   u'yp_info': u'ztWMNva0qN2z%2FrEWVrjV4eUeh13Xr834640aRMeBoGXfs3lB',
#   u'yw_num': u'2',
#   u'yz_num': u'38',
#   u'ze_num': u'--',
#   u'zy_num': u'--'},
#  {u'arrive_time': u'00:42',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'1',
#   u'end_city_code': u'0802',
#   u'end_province_code': u'09',
#   u'end_station_name': u'\u4eb3\u5dde',
#   u'end_station_telecode': u'BZH',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'0',
#   u'lishi': u'01:01',
#   u'lishiValue': u'61',
#   u'location_code': u'H3',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'4',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'W3431333',
#   u'seat_types': u'1413',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'23:41',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'K8366',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000K836640',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'3',
#   u'tz_num': u'--',
#   u'wz_num': u'58',
#   u'yb_num': u'--',
#   u'yp_ex': u'10401030',
#   u'yp_info': u'vTatHz800yanqUctnXe4VXSRPPQ0eF8MLu7g69V0a8hvV0%2BuZ0U6o66TJoo%3D',
#   u'yw_num': u'20',
#   u'yz_num': u'137',
#   u'ze_num': u'--',
#   u'zy_num': u'--'},
#  {u'arrive_time': u'00:49',
#   u'canWebBuy': u'Y',
#   u'control_day': 29,
#   u'control_train_day': u'20300303',
#   u'controlled_train_flag': u'0',
#   u'controlled_train_message': u'\u6b63\u5e38\u8f66\u6b21\uff0c\u4e0d\u53d7\u63a7',
#   u'day_difference': u'1',
#   u'end_city_code': u'1221',
#   u'end_province_code': u'13',
#   u'end_station_name': u'\u5468\u53e3',
#   u'end_station_telecode': u'ZKN',
#   u'from_station_name': u'\u4e0a\u6d77',
#   u'from_station_no': u'01',
#   u'from_station_telecode': u'SHH',
#   u'gg_num': u'--',
#   u'gr_num': u'--',
#   u'is_support_card': u'0',
#   u'lishi': u'01:02',
#   u'lishiValue': u'62',
#   u'location_code': u'H1',
#   u'note': u'',
#   u'qt_num': u'--',
#   u'rw_num': u'5',
#   u'rz_num': u'--',
#   u'sale_time': u'1430',
#   u'seat_feature': u'W3431333',
#   u'seat_types': u'1413',
#   u'start_city_code': u'0712',
#   u'start_province_code': u'33',
#   u'start_station_name': u'\u4e0a\u6d77',
#   u'start_station_telecode': u'SHH',
#   u'start_time': u'23:47',
#   u'start_train_date': u'20161229',
#   u'station_train_code': u'K1506',
#   u'swz_num': u'--',
#   u'to_station_name': u'\u82cf\u5dde',
#   u'to_station_no': u'03',
#   u'to_station_telecode': u'SZH',
#   u'train_class_name': u'',
#   u'train_no': u'55000K150602',
#   u'train_seat_feature': u'3',
#   u'train_type_code': u'2',
#   u'tz_num': u'--',
#   u'wz_num': u'\u65e0',
#   u'yb_num': u'--',
#   u'yp_ex': u'10401030',
#   u'yp_info': u'oFaSnPYLblBH1d8obNMxYgkgOPpctYhacZwsXeignXjgRrD8xuxu%2FxDkIpw%3D',
#   u'yw_num': u'63',
#   u'yz_num': u'549',
#   u'ze_num': u'--',
#   u'zy_num': u'--'}]

# %% [markdown]
# ## 1.2将数据读入pandas并进行处理后保存

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(data)
df.tail()
# Out:
#     arrive_time canWebBuy  control_day control_train_day  \
# 217       00:16         Y           29          20300303
# 218       00:22         Y           29          20300303
# 219       00:36         Y           29          20300303
# 220       00:42         Y           29          20300303
# 221       00:49         Y           29          20300303
#
#     controlled_train_flag controlled_train_message day_difference  \
# 217                     0                 正常车次，不受控              1
# 218                     0                 正常车次，不受控              1
# 219                     0                 正常车次，不受控              1
# 220                     0                 正常车次，不受控              1
# 221                     0                 正常车次，不受控              1
#
#     end_city_code end_province_code end_station_name  ...   train_type_code  \
# 217          0804                09               阜阳  ...                 3
# 218          0801                09               淮北  ...                 3
# 219          0804                09               阜阳  ...                 3
# 220          0802                09               亳州  ...                 3
# 221          1221                13               周口  ...                 2
#
#     tz_num wz_num yb_num     yp_ex  \
# 217     --      无     --  10401030
# 218     --    426     --  10401030
# 219     --      无     --    101030
# 220     --     58     --  10401030
# 221     --      无     --  10401030
#
#                                                yp_info yw_num yz_num ze_num  \
# 217  Sn3H293kvwh1ddPgE58mMLOFKLV%2BGVvGGKnzhGFlfDdN...      无    121     --
# 218  xDvvVP85XhCaWT9yL6qHcf6vL%2BwZ6CeOn0EWcnuOCek2...      7     37     --
# 219  ztWMNva0qN2z%2FrEWVrjV4eUeh13Xr834640aRMeBoGXf...      2     38     --
# 220  ePaUod%2FI6IbvX4M0HLAKovQUvmCgM3vawnswhrGOy2WU...     21    136     --
# 221  YGEHeFgIkaEfW3eI62yg5P4PtIfnN8PlOKPFhFYfyPyuOE...     62    549     --
#
#     zy_num
# 217     --
# 218     --
# 219     --
# 220     --
# 221     --
#
# [5 rows x 51 columns]

# %%
df.columns
# Out:
# Index([u'arrive_time', u'canWebBuy', u'control_day', u'control_train_day',
#        u'controlled_train_flag', u'controlled_train_message',
#        u'day_difference', u'end_city_code', u'end_province_code',
#        u'end_station_name', u'end_station_telecode', u'from_station_name',
#        u'from_station_no', u'from_station_telecode', u'gg_num', u'gr_num',
#        u'is_support_card', u'lishi', u'lishiValue', u'location_code', u'note',
#        u'qt_num', u'rw_num', u'rz_num', u'sale_time', u'seat_feature',
#        u'seat_types', u'start_city_code', u'start_province_code',
#        u'start_station_name', u'start_station_telecode', u'start_time',
#        u'start_train_date', u'station_train_code', u'swz_num',
#        u'to_station_name', u'to_station_no', u'to_station_telecode',
#        u'train_class_name', u'train_no', u'train_seat_feature',
#        u'train_type_code', u'tz_num', u'wz_num', u'yb_num', u'yp_ex',
#        u'yp_info', u'yw_num', u'yz_num', u'ze_num', u'zy_num'],
#       dtype='object')

# %%
df_use = df[[u'train_no',
            u'station_train_code',
             u'from_station_name',
             u'to_station_name',
             u'start_time',
             u'swz_num',
             u'tz_num',  #特等座
             u'zy_num',
             u'ze_num',
             u'wz_num',
             ]]

# %%
df_use = df_use[df_use[u'station_train_code'].str.startswith('G') | \
       df_use[u'station_train_code'].str.startswith('D')]
df_use.head()
# Out:
#        train_no station_train_code from_station_name to_station_name  \
# 2  5l0000D63630               D636              上海虹桥              苏州
# 3  5l000G191200              G1912              上海虹桥             苏州北
# 4  55000G703240              G7032                上海              苏州
# 5  5l000G180200              G1802              上海虹桥             苏州北
# 6  55000G7076A0              G7076                上海              苏州
#
#   start_time swz_num tz_num zy_num ze_num wz_num
# 2      06:09      --     --     12     73      无
# 3      06:17      23     --    160    708     --
# 4      06:18      --     --     50    522      无
# 5      06:22       无     --     17    449     --
# 6      06:23      --     --      3     63      无

# %%
df_use.replace('--',0,inplace=True) # 注意：--是指无此席位，并非指无余票
df_use.replace(u'无',0,inplace=True)

# %%
# df_use.reset_index(inplace=True)
df_use.head()
# Out:
#        train_no station_train_code from_station_name to_station_name  \
# 2  5l0000D63630               D636              上海虹桥              苏州
# 3  5l000G191200              G1912              上海虹桥             苏州北
# 4  55000G703240              G7032                上海              苏州
# 5  5l000G180200              G1802              上海虹桥             苏州北
# 6  55000G7076A0              G7076                上海              苏州
#
#   start_time swz_num tz_num zy_num ze_num wz_num
# 2      06:09       0      0     12     73      0
# 3      06:17      23      0    160    708      0
# 4      06:18       0      0     50    522      0
# 5      06:22       0      0     17    449      0
# 6      06:23       0      0      3     63      0

# %%
df_use.to_csv('./data/TEST2016-12-29-SH-SZ.csv',encoding='utf-8')

# %% [markdown]
# ## 1.3一个完整代码

# %%
import requests
import pandas as pd
import json
#import arrow
import warnings
warnings.filterwarnings("ignore")

def get_pd(para):
    para = para
    r = requests.get('https://kyfw.12306.cn/otn/lcxxcx/query?purpose_codes=ADULT&' + \
                     para, verify=False).text
    return r

def to_csv(js):
    js2 = json.loads(js)
    data = js2['data']['datas']
    df = pd.DataFrame(data)
    df_use = df[[u'train_no',
            u'station_train_code',
                 u'from_station_name',
                 u'to_station_name',
                 u'start_time',
                 u'swz_num',
                 u'tz_num',
                 u'zy_num',
                 u'ze_num',
                 u'wz_num',
                 ]]
    df_use = df_use[df_use[u'station_train_code'].str.startswith('G') | \
    df_use[u'station_train_code'].str.startswith('D')]
    df_use.replace('--',0,inplace=True)
    df_use.replace(u'无',0,inplace=True)
#     tm = arrow.now().format('HH:mm:ss')
#     df_use['record_time'] = tm
    df_use.to_csv('./data/TEST2016-12-29-SH-NJ.csv',index=False,encoding='utf-8')
if __name__ == '__main__':
    para = 'queryDate=2016-12-29&from_station=SHH&to_station=NJH'
    js = get_pd(para)
    to_csv(js)
    print('finished')
# Out:
# finished

# %% [markdown]
# #### 多sheet录入
# >writer = pd.ExcelWriter('./data/ht2016-12-10-SH-NJ.xlsx') <br>
# >df_use.to_excel(writer,'Sheet1')<br>
# >df.to_excel(writer,'Sheet2') <br>
# >writer.save()<br>

# %% [markdown]
# #  2. 类-面向对象

# %% [markdown]
# ```
# hu_ning = ['SHH','KNH','SZH','WXH','CZH','DYH','ZJH','NJH']
# # station_ls_comb = []
# for i in range(0,len(hu_ning)-1):
#     ls = [hu_ning[i],hu_ning[i+1]]
# #     station_ls_comb.append(ls)
#     print ls
# # print station_ls_comb
# ```

# %%
hu_ning = ['SHH','KNH','SZH','WXH','CZH','DYH','ZJH','NJH']
ning_hu = ['NJH','ZJH','DYH','CZH','WXH','SZH','KNH','SHH']

# %% [markdown]
# ## 2.1进行站点之间组合

# %% [markdown]
# # $C^{2}_8$

# %%
from itertools import combinations
hu_ning = ['SHH','KNH','SZH','WXH','CZH','DYH','ZJH','NJH']
com = combinations(hu_ning,2)
for i in com:
    print i
# Out:
# ('SHH', 'KNH')
# ('SHH', 'SZH')
# ('SHH', 'WXH')
# ('SHH', 'CZH')
# ('SHH', 'DYH')
# ('SHH', 'ZJH')
# ('SHH', 'NJH')
# ('KNH', 'SZH')
# ('KNH', 'WXH')
# ('KNH', 'CZH')
# ('KNH', 'DYH')
# ('KNH', 'ZJH')
# ('KNH', 'NJH')
# ('SZH', 'WXH')
# ('SZH', 'CZH')
# ('SZH', 'DYH')
# ('SZH', 'ZJH')
# ('SZH', 'NJH')
# ('WXH', 'CZH')
# ('WXH', 'DYH')
# ('WXH', 'ZJH')
# ('WXH', 'NJH')
# ('CZH', 'DYH')
# ('CZH', 'ZJH')
# ('CZH', 'NJH')
# ('DYH', 'ZJH')
# ('DYH', 'NJH')
# ('ZJH', 'NJH')

# %% [markdown]
# ## 2.2抓取特定时间所有站点数据-运行一次

# %%
import requests
import pandas as pd
import json
import arrow
from itertools import combinations
import warnings
warnings.filterwarnings("ignore")

class HighSpeed(object):
    def __init__(self,date,from_station,to_station):
        self.date = date
        self.from_station = from_station
        self.to_station = to_station

    
#     url = 'https://kyfw.12306.cn/otn/lcxxcx/query?purpose_codes=ADULT
#     &queryDate=2016-12-29&from_station=SHH&to_station=SZH'

    def get_pd(self):
        para = 'queryDate=' + self.date + '&from_station=' + self.from_station \
               +'&to_station=' + self.to_station
        r = requests.get('https://kyfw.12306.cn/otn/lcxxcx/query?purpose_codes=ADULT&' + \
                         para, verify=False).text
        return r

    def to_csv(self):
        js = self.get_pd()
        js2 = json.loads(js)
        data = js2['data']['datas']
        df = pd.DataFrame(data)
        df_use = df[[u'train_no',
                u'station_train_code',
                     u'from_station_name',
                     u'to_station_name',
                     u'start_time',
                     u'swz_num',
                     u'tz_num',
                     u'zy_num',
                     u'ze_num',
                     u'wz_num',
                     ]]
        df_use = df_use[df_use[u'station_train_code'].str.startswith('G') | \
        df_use[u'station_train_code'].str.startswith('D')]
        df_use.replace('--',0,inplace=True)
        df_use.replace(u'无',0,inplace=True)    
        
        tm = arrow.now().format('HH:mm')
        df_use['record_time'] = tm
        
#         df_use = df_choose[df_choose['record_time'] == df_choose['start_time']]
      
        df_use.to_csv('./data/' + self.date + 'TEST.csv',
                       mode = 'a', index = False, 
                      column = False,
                      encoding='utf-8')
         
if __name__ == '__main__':
    date = '2016-12-29'    
    hu_ning = ['SHH','KNH','SZH','WXH','CZH','DYH','ZJH','NJH']
    com = combinations(hu_ning,2)
    for ls in com:
        hspeed = HighSpeed(date,ls[0],ls[1])
        hspeed.to_csv()
    print('finished')
# Out:
# finished

# %% [markdown]
# # 3.按时间自动抓取余票数据

# %% [markdown]
# ## 3.1 时间库与流程库

# %% [markdown]
# #### 流程控制库

# %%
import schedule
import time

def job():
    print("I'm working...")

schedule.every(1).minutes.do(job)
# schedule.every().hour.do(job)
# schedule.every().day.at("14:09").do(job)
# schedule.every().monday.do(job)
# schedule.every().wednesday.at("13:15").do(job)

while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# I'm working...
# I'm working...

# %% [markdown]
# #### 时间转换库

# %%
import arrow
tm = arrow.now()
print tm.format('HH:mm:ss')
    
tm_debefore30m = tm.replace(minutes=-30)
print tm_debefore30m
# Out:
# 14:59:06
# 2016-12-15T14:29:06.772000+08:00

# %%
tm2_debefore30m = tm.replace(minutes=-30).format('HH:mm')
print tm2_debefore30m
# Out:
# 13:46

# %%
date = arrow.now().format('YYYY-MM-DD')
date
# Out:
# u'2016-12-15'

# %% [markdown]
# ## 3.2 每间隔一分钟抓取一次，所有站点数据-运行一次

# %%
# -*- coding:utf-8 -*-

import requests
import pandas as pd
import json
import schedule
import time
import arrow
from itertools import combinations
import warnings
warnings.filterwarnings("ignore")


class HighSpeed(object):
    def __init__(self,date,from_station,to_station):
        self.date = date
        self.from_station = from_station
        self.to_station = to_station

    def get_pd(self):
        para = 'queryDate=' + self.date + '&from_station=' + self.from_station \
               +'&to_station=' + self.to_station
        r = requests.get('https://kyfw.12306.cn/otn/lcxxcx/query?purpose_codes=ADULT&' + \
                         para, verify=False).text
        return r

    def to_csv(self):
        js = self.get_pd()
        js2 = json.loads(js)
        data = js2['data']['datas']
        df = pd.DataFrame(data)
        df_use = df[[u'train_no',
                u'station_train_code',
                     u'from_station_name',
                     u'to_station_name',
                     u'start_time',
                     u'swz_num',
                     u'tz_num',
                     u'zy_num',
                     u'ze_num',
                     u'wz_num',
                     ]]
        df_use = df_use[df_use[u'station_train_code'].str.startswith('G') | \
        df_use[u'station_train_code'].str.startswith('D')]
        df_use.replace('--',0,inplace=True)
        df_use.replace(u'无',0,inplace=True)    
        
        tm = arrow.now()
        df_use['record_date'] = tm.format('YYYY-MM-DD')
        df_use['record_time'] = tm.format('HH:mm')
#         df_use = df_choose[df_choose['record_time'] == df_choose['start_time']]
      
        df_use.to_csv('./data/' + self.date + '.csv',
                      mode = 'a', index = False, 
                      header = False,encoding='utf-8')

    
        
if __name__ == '__main__':
       
    def process_hspeed():
        date = arrow.now().format('YYYY-MM-DD')    
        
        hu_ning = ['SHH','KNH','SZH','WXH','CZH','DYH','ZJH','NJH']
        com = combinations(hu_ning,2)
        for ls_hu_ning in com:
            hspeed = HighSpeed(date,ls_hu_ning[0],ls_hu_ning[1])
            hspeed.to_csv()
        
        ning_hu = ['NJH','ZJH','DYH','CZH','WXH','SZH','KNH','SHH']
        com = combinations(ning_hu,2)
        for ls_ning_hu in com:
            hspeed = HighSpeed(date,ls_ning_hu[0],ls_ning_hu[1])
            hspeed.to_csv()
            

    schedule.every(1).minutes.do(process_hspeed)
    # schedule.every().hour.do(job)
    # schedule.every().day.at("14:09").do(job)
    # schedule.every().monday.do(job)
    # schedule.every().wednesday.at("13:15").do(job)

    while True:
        schedule.run_pending()
        time.sleep(1)

# %% [markdown]
# # 4.判断可用数据

# %%
import pandas as pd
import arrow
df_hu_ning = pd.read_csv('./data/HuNing-2016-12-18.csv',encoding='utf-8')
df_hu_ning.tail()
# Out:
#         5l000G710600  G7106 上海虹桥  昆山南  11:05   0  0.1  20    9  150  \
# 581415  55000G7068A0  G7068   镇江   南京  21:59   0    0  45  387  168
# 581416  5l000G712660  G7126   镇江  南京南  22:04  18    0  52  974  294
# 581417  5l000G716821  G7168  镇江南  南京南  22:08   0   29  80  100  196
# 581418  55000G703050  G7030   镇江   南京  22:32   0    0  39  404  168
# 581419  5l000G7128A0  G7128   镇江   南京  22:43   0    0  47  459  168
#
#         2016-12-18  10:59
# 581415  2016-12-18  19:15
# 581416  2016-12-18  19:15
# 581417  2016-12-18  19:15
# 581418  2016-12-18  19:15
# 581419  2016-12-18  19:15

# %%
df_hu_ning.columns = [u'train_no',
    u'station_train_code',
                     u'from_station_name',
                     u'to_station_name',
                     u'start_time',
                     u'swz_num',
                     u'tz_num',
                     u'zy_num',
                     u'ze_num',
                     u'wz_num',
              u'record_date',
              u'record_time',]
df_hu_ning.tail()
# Out:
#             train_no station_train_code from_station_name to_station_name  \
# 581415  55000G7068A0              G7068                镇江              南京
# 581416  5l000G712660              G7126                镇江             南京南
# 581417  5l000G716821              G7168               镇江南             南京南
# 581418  55000G703050              G7030                镇江              南京
# 581419  5l000G7128A0              G7128                镇江              南京
#
#        start_time  swz_num  tz_num  zy_num  ze_num  wz_num record_date  \
# 581415      21:59        0       0      45     387     168  2016-12-18
# 581416      22:04       18       0      52     974     294  2016-12-18
# 581417      22:08        0      29      80     100     196  2016-12-18
# 581418      22:32        0       0      39     404     168  2016-12-18
# 581419      22:43        0       0      47     459     168  2016-12-18
#
#        record_time
# 581415       19:15
# 581416       19:15
# 581417       19:15
# 581418       19:15
# 581419       19:15

# %%
df_hu_ning[df_hu_ning['start_time'] == '13:45'].head(2)
# Out:
#          train_no station_train_code from_station_name to_station_name  \
# 109  5l000G181400              G1814              上海虹桥             苏州北
# 225  5l000G181400              G1814              上海虹桥             无锡东
#
#     start_time  swz_num  tz_num  zy_num  ze_num  wz_num record_date  \
# 109      13:45        5       0      22     377       0  2016-12-18
# 225      13:45        3       0      10     242       0  2016-12-18
#
#     record_time
# 109       10:59
# 225       10:59

# %%
df_hu_ning[(df_hu_ning['start_time'] == '13:45') & (df_hu_ning['record_time'] == '12:20')]
# Out:
#             train_no station_train_code from_station_name to_station_name  \
# 135901  5l000G181400              G1814              上海虹桥             苏州北
# 136001  5l000G181400              G1814              上海虹桥             无锡东
# 136203  5l000G181400              G1814              上海虹桥             镇江南
# 136271  5l000G181400              G1814              上海虹桥             南京南
#
#        start_time  swz_num  tz_num  zy_num  ze_num  wz_num record_date  \
# 135901      13:45        3       0      19     347       0  2016-12-18
# 136001      13:45        1       0       6     205       0  2016-12-18
# 136203      13:45        0       0       1     135       0  2016-12-18
# 136271      13:45        0       0       1      70       0  2016-12-18
#
#        record_time
# 135901       12:20
# 136001       12:20
# 136203       12:20
# 136271       12:20

# %% [markdown]
# ## 4.1 筛选出发车时间前30分钟的余票信息

# %% [markdown]
# > 上海——南京，最早发车时间为06:02，最后一个区间是	22:43  G7128  镇江至南京，<br>
# > 南京——上海，最早发车时间为03:30，最后一个区间是	22:43  G7128  镇江至南京，

# %%
df_hu_ning2 = df_hu_ning[(df_hu_ning['start_time'].str.contains("0[6-9]:|1[0-9]:|2[0-3]:"))]
df_hu_ning2['start_time'].sort_values(ascending=True).head()
# Out:
# 506     10:46
# 505     10:46
# 4017    10:48
# 1970    10:48
# 2694    10:51
# Name: start_time, dtype: object

# %%
df_hu_ning2.head()
# Out:
#        train_no station_train_code from_station_name to_station_name  \
# 0  5j000G757240              G7572              上海虹桥             昆山南
# 1  55000G726472              G7264                上海             昆山南
# 2  5l000G122860              G1228              上海虹桥             昆山南
# 3  55000G728200              G7282                上海             昆山南
# 4  5l000G710800              G7108              上海虹桥             昆山南
#
#   start_time  swz_num  tz_num  zy_num  ze_num  wz_num record_date record_time
# 0      11:10        0       0      41      76     335  2016-12-18       10:59
# 1      11:17        0       0      11       0     108  2016-12-18       10:59
# 2      11:31       19       0      35     684       0  2016-12-18       10:59
# 3      11:34        0       0      33       6     156  2016-12-18       10:59
# 4      11:40        8       0      18     340     147  2016-12-18       10:59

# %%
time_choose = arrow.now()
print time_choose
time_before_30m = time_choose.replace(minutes=-30).format('HH:mm')
print time_before_30m
# Out:
# 2016-12-18T20:11:15.578329+08:00
# 19:41

# %% [markdown]
# #### 小记录：开车前30分钟

# %%
df_hu_ning2['start_time'].head()
# Out:
# 0    11:10
# 1    11:17
# 2    11:31
# 3    11:34
# 4    11:40
# Name: start_time, dtype: object

# %%
arrow.get('08:05', 'HH:mm').replace(minutes=-30).format('HH:mm')
# Out:
# '07:35'

# %%
df_hu_ning2['start_time'].apply(lambda x: arrow.get(x, 'HH:mm').replace(minutes=-30).format('HH:mm')).head()
# Out:
# 0    10:40
# 1    10:47
# 2    11:01
# 3    11:04
# 4    11:10
# Name: start_time, dtype: object

# %% [markdown]
# #### 添加列，记录开车前30分钟数据

# %%
df_hu_ning2['start_time_before30m'] = df_hu_ning2['start_time'].apply(lambda x: arrow.get(x, 'HH:mm')\
                                                      .replace(minutes=-30).format('HH:mm'))
df_hu_ning2.head()
# Out:
#        train_no station_train_code from_station_name to_station_name  \
# 0  5j000G757240              G7572              上海虹桥             昆山南
# 1  55000G726472              G7264                上海             昆山南
# 2  5l000G122860              G1228              上海虹桥             昆山南
# 3  55000G728200              G7282                上海             昆山南
# 4  5l000G710800              G7108              上海虹桥             昆山南
#
#   start_time  swz_num  tz_num  zy_num  ze_num  wz_num record_date record_time  \
# 0      11:10        0       0      41      76     335  2016-12-18       10:59
# 1      11:17        0       0      11       0     108  2016-12-18       10:59
# 2      11:31       19       0      35     684       0  2016-12-18       10:59
# 3      11:34        0       0      33       6     156  2016-12-18       10:59
# 4      11:40        8       0      18     340     147  2016-12-18       10:59
#
#   start_time_before30m
# 0                10:40
# 1                10:47
# 2                11:01
# 3                11:04
# 4                11:10

# %% [markdown]
# #### 记录时间==发车前30分钟数据，（高价值数据）

# %%
df_hu_ning2[df_hu_ning2['start_time_before30m'] == df_hu_ning2['record_time']].head(5)
# Out:
#           train_no station_train_code from_station_name to_station_name  \
# 1707  5l000G713670              G7136               戚墅堰              丹阳
# 1740  5l000G713670              G7136               戚墅堰              镇江
# 1797  5l000G713670              G7136               戚墅堰             南京南
# 1893  55000G704290              G7042                丹阳              镇江
# 1925  55000G704290              G7042                丹阳              南京
#
#      start_time  swz_num  tz_num  zy_num  ze_num  wz_num record_date  \
# 1707      11:29        0       0      15      16     135  2016-12-18
# 1740      11:29        0       0      15      10     135  2016-12-18
# 1797      11:29        0       0      15       9     135  2016-12-18
# 1893      11:29       10       0      16     178     147  2016-12-18
# 1925      11:29       10       0      16     174     147  2016-12-18
#
#      record_time start_time_before30m
# 1707       10:59                10:59
# 1740       10:59                10:59
# 1797       10:59                10:59
# 1893       10:59                10:59
# 1925       10:59                10:59

# %% [markdown]
# #### df3为可用数据

# %%
df_hu_ning3 = df_hu_ning2[df_hu_ning2['start_time_before30m'] == df_hu_ning2['record_time']]
print len(df_hu_ning3)
# Out:
# 1267

# %%
df_hu_ning3[df_hu_ning3['station_train_code'] == 'G130']
# Out:
#            train_no station_train_code from_station_name to_station_name  \
# 59238  5l0000G13061               G130               无锡东             常州北
# 59419  5l0000G13061               G130               无锡东             南京南
# 91919  5l0000G13061               G130               常州北             南京南
#
#       start_time  swz_num  tz_num  zy_num  ze_num  wz_num record_date  \
# 59238      12:03       13       0      18     577       0  2016-12-18
# 59419      12:03       12       0      16     532       0  2016-12-18
# 91919      12:22       10       0      14     523       0  2016-12-18
#
#       record_time start_time_before30m
# 59238       11:33                11:33
# 59419       11:33                11:33
# 91919       11:52                11:52

# %% [markdown]
# #### 加一条列，记录起止站数据

# %%
df_hu_ning3['from_to'] = np.nan
df_hu_ning3['from_to'] = df_hu_ning3['from_station_name'] + ',' +df_hu_ning3['to_station_name']
df_hu_ning3['from_to'] = df_hu_ning3['from_to'].str.split(',')
df_hu_ning3.head(2)
# Out:
#           train_no station_train_code from_station_name to_station_name  \
# 1707  5l000G713670              G7136               戚墅堰              丹阳
# 1740  5l000G713670              G7136               戚墅堰              镇江
#
#      start_time  swz_num  tz_num  zy_num  ze_num  wz_num record_date  \
# 1707      11:29        0       0      15      16     135  2016-12-18
# 1740      11:29        0       0      15      10     135  2016-12-18
#
#      record_time start_time_before30m    from_to
# 1707       10:59                10:59  [戚墅堰, 丹阳]
# 1740       10:59                10:59  [戚墅堰, 镇江]

# %%
type(df_hu_ning3['from_to'][1707])
# Out:
# list

# %% [markdown]
# #### from_to为列表

# %%
df_hu_ning3.from_to[1707]
# Out:
# [u'\u621a\u5885\u5830', u'\u4e39\u9633']

# %%
df_hu_ning3['from_to'][1740]
# Out:
# [u'\u621a\u5885\u5830', u'\u9547\u6c5f']

# %%
df_hu_ning3.to_json('./data/df_hu_ning.json')

# %%
df_test = pd.read_json('./data/df_hu_ning.json')

# %%
df_test.head(2)
# Out:
#        from_station_name     from_to record_date         record_time  \
# 10141                镇江南  [镇江南, 南京南]  2016-12-18 2016-12-18 11:05:00
# 103186               镇江南  [镇江南, 南京南]  2016-12-18 2016-12-18 11:59:00
#
#                 start_time start_time_before30m station_train_code  swz_num  \
# 10141  2016-12-18 11:35:00                11:05              G1214        0
# 103186 2016-12-18 12:29:00                11:59              G1252       11
#
#        to_station_name      train_no  tz_num  wz_num  ze_num  zy_num
# 10141              南京南  5l000G121460      28       0     576      70
# 103186             南京南  5l000G125240       0       0     698      38

# %%
df_test.ix[10141,'from_to']
# Out:
# [u'\u9547\u6c5f\u5357', u'\u5357\u4eac\u5357']

# %% [markdown]
# ## 2.2 汇总前一区间与下一区间的余票，并计算站点的上下客情况。

# %% [markdown]
# >step1:添加一列，统计余票总数（如果有可能，可去获取上车多少人？）;<br>
# >step2:前一个数据减后一个数据，即可获得中间站的上下客情况。
#
# >中间站即为下一条数据的from_station_name

# %% [markdown]
# # 二、获取各车次区间情况

# %% [markdown]
# # 1. 区间站信息获取

# %% [markdown]
# ## 1.1 获取沪宁-宁沪线车次

# %% [markdown]
# https://kyfw.12306.cn/otn/czxx/queryByTrainNo?train_no=5l000G191200&from_station_telecode=SHH&to_station_telecode=NJH&depart_date=2016-12-23

# %%
import requests
import pandas as pd
import json
#import arrow
import warnings
warnings.filterwarnings("ignore")

def get_pd(para):
    para = para
    r = requests.get('https://kyfw.12306.cn/otn/lcxxcx/query?purpose_codes=ADULT&' + \
                     para, verify=False).text
    return r

def to_csv(js):
    js2 = json.loads(js)
    data = js2['data']['datas']
    df = pd.DataFrame(data)
    df_use = df[[u'train_no',
            u'station_train_code',
                 u'from_station_name',
                 u'to_station_name',
                 u'start_time',
                 u'swz_num',
                 u'tz_num',
                 u'zy_num',
                 u'ze_num',
                 u'wz_num',
                 ]]
    df_use = df_use[df_use[u'station_train_code'].str.startswith('G') | \
    df_use[u'station_train_code'].str.startswith('D')]
    df_use.replace('--',0,inplace=True)
    df_use.replace(u'无',0,inplace=True)
#     tm = arrow.now().format('HH:mm:ss')
#     df_use['record_time'] = tm
    df_use[u'train_no'].to_csv('./data/SH-NJ-train_no.csv',index=False,encoding='utf-8')
#     df_use[u'train_no'].to_csv('./data/NJ-SH-train_no.csv',index=False,encoding='utf-8')
    
if __name__ == '__main__':
    para = 'queryDate=2016-12-29&from_station=SHH&to_station=NJH'
#     para = 'queryDate=2016-12-29&from_station=NJH&to_station=SHH'
    js = get_pd(para)
    to_csv(js)
    print('finished')
# Out:
# finished

# %% [markdown]
# ## 1.2 获取各车次，站点信息

# %% [markdown]
# #### 3个参数需要调整

# %%
import requests
import pandas as pd
import json
#import arrow
import warnings
warnings.filterwarnings("ignore")


def get_pd(para):
    para = para
    r = requests.get('https://kyfw.12306.cn/otn/czxx/queryByTrainNo?train_no='+para+\
                     '&from_station_telecode=NJH&to_station_telecode=SHH&depart_date=2016-12-29',
                     verify=False).text
    return r

def to_csv(para,js):
    js2 = json.loads(js)
    data = js2['data']['data']
    df = pd.DataFrame(data)
    try:
        df = df[["station_name",]]
        df_use = pd.DataFrame({'train_no':[''],'station_name':['']})
        df_use['train_no'] = para.strip()
        df_use['station_name'] = df_use['station_name'].apply(lambda x: df["station_name"].values)
    #     df_use['start_time'] = df_use['start_time'].apply(lambda x: df["start_time"].values)
    #     df_use = df_use[df_use[u'station_train_code'].str.startswith('G') | \
    #     df_use[u'station_train_code'].str.startswith('D')]
    #     df_use.replace('--',0,inplace=True)
    #     df_use.replace(u'无',0,inplace=True)
    #     tm = arrow.now().format('HH:mm:ss')
    #     df_use['record_time'] = tm
        df_use.to_csv('./data/NJ-SH-station.csv',mode = 'a',index=False,header=False,encoding='utf-8')
    except:
        pass
if __name__ == '__main__':
#     para = '55000G707270'
#     js = get_pd(para)
#     to_csv(para,js)
#     print('finished')
    station_no_file = open('./data/NJ-SH-train_no.csv','r')
    station_no_data = station_no_file.readlines()
    for station_no in station_no_data:
#         print station_no.strip()
#         para = '55000G707270'
        js = get_pd(station_no.strip())
        to_csv(station_no.strip(),js)
    print('finished')
# Out:
# finished

# %% [markdown]
# #### 读取信息

# %%
df_SH_NJ = pd.read_csv('./data/SH-NJ-station.csv',encoding='utf-8')
df_SH_NJ.tail()
# Out:
#     [上海, 无锡, 常州, 丹阳, 镇江, 宝华山, 南京南, 马鞍山东, 当涂东, 芜湖, 弋江, 铜陵, 池州, 安庆]  \
# 198                                  [上海, 苏州, 南京, 北京南]
# 199                    [上海虹桥, 昆山南, 苏州, 无锡, 常州, 镇江, 南京]
# 200  [深圳北, 惠州南, 惠东, 汕尾, 潮阳, 潮汕, 诏安, 漳浦, 漳州, 厦门北, 泉州...
# 201  [苍南, 鳌江, 温州南, 青田, 丽水, 缙云西, 永康南, 武义北, 义乌, 杭州东, ...
# 202   [上海, 苏州, 南京, 徐州, 郑州东, 洛阳龙门, 三门峡南, 华山北, 渭南北, 西安北]
#
#      55000G707270
# 198  550000D31490
# 199  5l000G7128A0
# 200  6i000D228207
# 201  5j000G735010
# 202  550000D30661

# %%
len(df_SH_NJ)
# Out:
# 203

# %%
df_SH_NJ.columns=['station_name','train_no']
df_SH_NJ[df_SH_NJ.train_no == '55000G701081']
# Out:
#             station_name      train_no
# 74  [上海, 苏州, 无锡, 常州, 南京]  55000G701081

# %% [markdown]
# #### 添加列，进行组合

# %%
print df_SH_NJ['station_name'][0]
# Out:
# [上海虹桥, 无锡, 常州, 镇江, 南京南, 合肥南, 六安, 金寨, 麻城北, 汉口, 荆州, 宜昌东, 建始, 恩施, 利川, 石柱县, 涪陵北, 重庆北, 潼南, 遂宁, 成都东]

# %%
df_SH_NJ['station_name'][0]
# Out:
# u'[\u4e0a\u6d77\u8679\u6865, \u65e0\u9521, \u5e38\u5dde, \u9547\u6c5f, \u5357\u4eac\u5357, \u5408\u80a5\u5357, \u516d\u5b89, \u91d1\u5be8, \u9ebb\u57ce\u5317, \u6c49\u53e3, \u8346\u5dde, \u5b9c\u660c\u4e1c, \u5efa\u59cb, \u6069\u65bd, \u5229\u5ddd, \u77f3\u67f1\u53bf, \u6daa\u9675\u5317, \u91cd\u5e86\u5317, \u6f7c\u5357, \u9042\u5b81, \u6210\u90fd\u4e1c]'

# %%
df_SH_NJ['station_name'] = df_SH_NJ['station_name'].apply(lambda x: \
                                              x.replace(u'[',u'').replace(u']',u'').replace(' ','').split(','))

# %%
df_SH_NJ.tail()
# Out:
#                                           station_name      train_no
# 198                                  [上海, 苏州, 南京, 北京南]  550000D31490
# 199                    [上海虹桥, 昆山南, 苏州, 无锡, 常州, 镇江, 南京]  5l000G7128A0
# 200  [深圳北, 惠州南, 惠东, 汕尾, 潮阳, 潮汕, 诏安, 漳浦, 漳州, 厦门北, 泉州...  6i000D228207
# 201  [苍南, 鳌江, 温州南, 青田, 丽水, 缙云西, 永康南, 武义北, 义乌, 杭州东, ...  5j000G735010
# 202   [上海, 苏州, 南京, 徐州, 郑州东, 洛阳龙门, 三门峡南, 华山北, 渭南北, 西安北]  550000D30661

# %%
type(df_SH_NJ['station_name'][0])
# Out:
# list

# %%
len(df_SH_NJ['station_name'][0])
# Out:
# 21

# %% [markdown]
# [上海虹桥, 无锡, 常州, 镇江, 南京南, 合肥南, 六安, 金寨, 麻城北, 汉口, 荆州, 宜昌东, 建始, 恩施, 利川, 石柱县, 涪陵北, 重庆北, 潼南, 遂宁, 成都东]

# %% [markdown]
# ### 示例：将2数进行组合（zip与map函数、join方法的用法）

# %%
seq1 = ['one0', 'one1', 'one2']
seq2 = ['two0', 'two1', 'two2']
zip(seq1, seq2)
# Out:
# [('one0', 'two0'), ('one1', 'two1'), ('one2', 'two2')]

# %%
seq = ['one0', 'one1', 'one2', 'two0', 'two1', 'two2']
com= map(list,zip(seq[:-1], seq[1:]))
com
# Out:
# [['one0', 'one1'],
#  ['one1', 'one2'],
#  ['one2', 'two0'],
#  ['two0', 'two1'],
#  ['two1', 'two2']]

# %%
','.join(com[0])
# Out:
# 'one0,one1'

# %%
my_df['B'] = my_df.A.apply(lambda x: list(map(list, zip(x[:-1], x[1:]))))
my_df

# %%
dm = df_SH_NJ.copy()

# %%
dm['station_interval'] = dm['station_name'].apply(lambda x: list(map(list, zip(x[:-1], x[1:]))))
dm.head()
# Out:
#                                         station_name      train_no  \
# 0  [上海虹桥, 无锡, 常州, 镇江, 南京南, 合肥南, 六安, 金寨, 麻城北, 汉口, ...  5l0000D35270
# 1  [上海虹桥, 苏州, 无锡, 常州, 镇江, 南京南, 全椒, 肥东, 合肥南, 六安, 金...  5l0000D63630
# 2  [上海虹桥, 无锡东, 常州北, 镇江南, 南京南, 蚌埠南, 徐州东, 枣庄, 曲阜东, ...  5l0000G45630
# 3  [上海虹桥, 苏州北, 常州北, 镇江南, 南京南, 蚌埠南, 徐州东, 砀山南, 商丘, ...  5l000G191200
# 4                  [上海, 昆山南, 苏州, 无锡, 常州, 丹阳, 镇江, 南京]  55000G703240
#
#                                     station_interval
# 0  [[上海虹桥, 无锡], [无锡, 常州], [常州, 镇江], [镇江, 南京南], [南...
# 1  [[上海虹桥, 苏州], [苏州, 无锡], [无锡, 常州], [常州, 镇江], [镇江...
# 2  [[上海虹桥, 无锡东], [无锡东, 常州北], [常州北, 镇江南], [镇江南, 南京...
# 3  [[上海虹桥, 苏州北], [苏州北, 常州北], [常州北, 镇江南], [镇江南, 南京...
# 4  [[上海, 昆山南], [昆山南, 苏州], [苏州, 无锡], [无锡, 常州], [常州...

# %%
dm.station_interval[4]
# Out:
# [[u'\u4e0a\u6d77', u'\u6606\u5c71\u5357'],
#  [u'\u6606\u5c71\u5357', u'\u82cf\u5dde'],
#  [u'\u82cf\u5dde', u'\u65e0\u9521'],
#  [u'\u65e0\u9521', u'\u5e38\u5dde'],
#  [u'\u5e38\u5dde', u'\u4e39\u9633'],
#  [u'\u4e39\u9633', u'\u9547\u6c5f'],
#  [u'\u9547\u6c5f', u'\u5357\u4eac']]

# %%
type(dm['station_interval'][0][0])
# Out:
# list

# %%
dm.to_json('./data/df_hu_station_modifity.json')

# %% [markdown]
# # 三、余票数据与站点区间数据比对，获取是相邻站点的余票数据信息

# %%
import pandas as pd
import numpy as np
df_tickets = pd.read_json('./data/df_hu_ning.json')
df_tickets[df_tickets['train_no']=='55000G701081']
# Out:
#       from_station_name   from_to record_date         record_time  \
# 25738                无锡  [无锡, 常州]  2016-12-18 2016-12-19 11:14:00
# 25926                无锡  [无锡, 南京]  2016-12-18 2016-12-19 11:14:00
# 53780                常州  [常州, 南京]  2016-12-18 2016-12-19 11:30:00
#
#                start_time start_time_before30m station_train_code  swz_num  \
# 25738 2016-12-19 11:44:00                11:14              G7010        0
# 25926 2016-12-19 11:44:00                11:14              G7010        0
# 53780 2016-12-19 12:00:00                11:30              G7010        0
#
#       to_station_name      train_no  tz_num  wz_num  ze_num  zy_num
# 25738              常州  55000G701081      24     294     664      32
# 25926              南京  55000G701081      24     294     650      32
# 53780              南京  55000G701081      24     294     670      38

# %%
len(df_tickets)
# Out:
# 1267

# %%
df_tickets.ix[99277,'from_to']
# Out:
# [u'\u5e38\u5dde\u5317', u'\u9547\u6c5f\u5357']

# %%
df_stations = pd.read_json('./data/df_hu_station_modifity.json')
df_stations[df_stations['train_no']=='55000G701081']
# Out:
#                             station_interval          station_name  \
# 74  [[上海, 苏州], [苏州, 无锡], [无锡, 常州], [常州, 南京]]  [上海, 苏州, 无锡, 常州, 南京]
#
#         train_no
# 74  55000G701081

# %%
df_stations.ix[74,'station_interval']
# Out:
# [[u'\u4e0a\u6d77', u'\u82cf\u5dde'],
#  [u'\u82cf\u5dde', u'\u65e0\u9521'],
#  [u'\u65e0\u9521', u'\u5e38\u5dde'],
#  [u'\u5e38\u5dde', u'\u5357\u4eac']]

# %%
len(df_stations)
# Out:
# 203

# %%
df_tickets_com = pd.merge(df_tickets,df_stations,on='train_no')
df_tickets_com[df_tickets_com['train_no']=='5l000G192400'].head(2)
# Out:
#    from_station_name     from_to record_date         record_time  \
# 22               常州北  [常州北, 镇江南]  2016-12-18 2016-12-19 12:02:00
# 23               常州北  [常州北, 南京南]  2016-12-18 2016-12-19 12:02:00
#
#             start_time start_time_before30m station_train_code  swz_num  \
# 22 2016-12-19 12:32:00                12:02              G1924        5
# 23 2016-12-19 12:32:00                12:02              G1924        5
#
#    to_station_name      train_no  tz_num  wz_num  ze_num  zy_num  \
# 22             镇江南  5l000G192400       0       0      46       4
# 23             南京南  5l000G192400       0       0      24       3
#
#                                      station_interval  \
# 22  [[上海虹桥, 无锡东], [无锡东, 常州北], [常州北, 镇江南], [镇江南, 南京...
# 23  [[上海虹桥, 无锡东], [无锡东, 常州北], [常州北, 镇江南], [镇江南, 南京...
#
#                                          station_name
# 22  [上海虹桥, 无锡东, 常州北, 镇江南, 南京南, 蚌埠南, 徐州东, 萧县北, 商丘, ...
# 23  [上海虹桥, 无锡东, 常州北, 镇江南, 南京南, 蚌埠南, 徐州东, 萧县北, 商丘, ...

# %%
len(df_tickets_com)
# Out:
# 1238

# %%
df_tickets_com.to_json('./data/df_tickets_com.json')

# %%
type(df_tickets_com['station_interval'][3][0])
# Out:
# list

# %%
df_tickets_com.ix[1,'from_to']
# Out:
# [u'\u9547\u6c5f\u5357', u'\u5357\u4eac\u5357']

# %% [markdown]
# ```
# print (my_df.apply(lambda x: x.A in x.B, axis=1))
# 0     True
# 1    False
# 2     True
# dtype: bool
# print (my_df[my_df.apply(lambda x: x.A in x.B, axis=1)])
#           A                               B
# 0  [aa, ab]  [[aa, ab], [ba, bb], [bc, bd]]
# 2  [bc, bd]            [[aa, ab], [bc, bd]]
# ```

# %%
del df_tickets_com['in']

# %%
df_tickets_com2 = df_tickets_com[df_tickets_com.apply(lambda x: x['from_to'] in x['station_interval'], axis=1)]
df_tickets_com2.head(2)
# Out:
#   from_station_name     from_to record_date         record_time  \
# 0               镇江南  [镇江南, 南京南]  2016-12-18 2016-12-19 11:05:00
# 1               镇江南  [镇江南, 南京南]  2016-12-18 2016-12-19 11:59:00
#
#            start_time start_time_before30m station_train_code  swz_num  \
# 0 2016-12-19 11:35:00                11:05              G1214        0
# 1 2016-12-19 12:29:00                11:59              G1252       11
#
#   to_station_name      train_no  tz_num  wz_num  ze_num  zy_num  \
# 0             南京南  5l000G121460      28       0     576      70
# 1             南京南  5l000G125240       0       0     698      38
#
#                                     station_interval  \
# 0  [[上海虹桥, 昆山南], [昆山南, 无锡东], [无锡东, 镇江南], [镇江南, 南京...
# 1  [[上海虹桥, 苏州北], [苏州北, 无锡东], [无锡东, 镇江南], [镇江南, 南京...
#
#                                         station_name
# 0  [上海虹桥, 昆山南, 无锡东, 镇江南, 南京南, 宿州东, 徐州东, 曲阜东, 济南西,...
# 1  [上海虹桥, 苏州北, 无锡东, 镇江南, 南京南, 滁州, 徐州东, 滕州东, 曲阜东, ...

# %%
len(df_tickets_com2)
# Out:
# 377

# %%
df_tickets_com2.to_json('./df_tickets_to_analysi.json')

# %%
dff = pd.read_json('./df_tickets_to_analysi.json')
dff.head(2)
# Out:
#   from_station_name     from_to record_date         record_time  \
# 0               镇江南  [镇江南, 南京南]  2016-12-18 2016-12-18 11:05:00
# 1               镇江南  [镇江南, 南京南]  2016-12-18 2016-12-18 11:59:00
#
#            start_time start_time_before30m  \
# 0 2016-12-18 11:35:00                11:05
# 1 2016-12-18 12:29:00                11:59
#
#                                     station_interval  \
# 0  [[上海虹桥, 昆山南], [昆山南, 无锡东], [无锡东, 镇江南], [镇江南, 南京...
# 1  [[上海虹桥, 苏州北], [苏州北, 无锡东], [无锡东, 镇江南], [镇江南, 南京...
#
#                                         station_name station_train_code  \
# 0  [上海虹桥, 昆山南, 无锡东, 镇江南, 南京南, 宿州东, 徐州东, 曲阜东, 济南西,...              G1214
# 1  [上海虹桥, 苏州北, 无锡东, 镇江南, 南京南, 滁州, 徐州东, 滕州东, 曲阜东, ...              G1252
#
#    swz_num to_station_name      train_no  tz_num  wz_num  ze_num  zy_num
# 0        0             南京南  5l000G121460      28       0     576      70
# 1       11             南京南  5l000G125240       0       0     698      38

# %%
dff.groupby(by=['from_station_name','to_station_name']).sum()
# Out:
#                                    swz_num  tz_num  wz_num  ze_num  zy_num
# from_station_name to_station_name
# 上海                南京南                    0       0      55       0       0
#                   昆山南                   36       0    1246    1395     225
#                   苏州                     0      54    1155     610      80
#                   苏州北                    0       0     157       2      23
# 上海虹桥              南京南                   18       0       0     408       6
#                   常州北                    0       0     157      46      23
#                   无锡东                   37       0       0     757     100
#                   昆山南                  202       0    2658    7606     853
#                   苏州                     1       0      74       0       2
#                   苏州北                  121      27     106    3923     499
#                   镇江南                   20       0       0     131     134
# 丹阳                南京                     0       0     548     737     126
#                   南京南                   12       0     291     119      74
#                   镇江                    67       0    1858    2282     404
# 丹阳北               南京南                   44       0       0     764     220
#                   镇江南                    0       0     141      13      19
# 常州                丹阳                    80       0    2231    2938     594
#                   南京                     0      96    1548    2140     183
#                   南京南                    0       0     188      72      15
#                   镇江                    14      28    1034     750     132
# 常州北               丹阳北                   11       0     142     554      25
#                   南京南                   83      28     281    1882     311
#                   镇江南                   86       0     197    2227     267
# 戚墅堰               丹阳                     2       0     179      96      24
# 无锡                丹阳                     9       0     440     643      94
#                   常州                   108      94    4320    4434     728
#                   戚墅堰                    2       0      21       6       2
# 无锡东               南京南                   68       0     161     962     129
#                   常州北                   92       5     270    2484     437
#                   镇江南                   49       0     240    1802     263
# 昆山南               丹阳北                   31       0       0     335     147
#                   常州北                   14       0       0     968      29
#                   无锡东                   39       0      85    1408     126
#                   苏州                   110       0    3213    1957     452
#                   苏州北                   76       0     384    1854     315
# 苏州                无锡                    89      78    4204    3536     650
#                   无锡新区                   0       0      51       0       0
# 苏州北               丹阳北                    7       0       0      37      59
#                   南京南                   45       0       0     865     146
#                   常州北                   28      21       0    1099      96
#                   无锡东                  119       7     361    3225     523
#                   镇江南                   26       0       0     571      59
# 苏州园区              无锡                     0       0      61     181      12
# 镇江                南京                    29      33    1594    1320     285
#                   南京南                   78       0    1780    1644     390
# 镇江南               南京南                  161      38     386    3821     753
# 阳澄湖               苏州园区                   0       0       3      31       0
